# %% [markdown]
# <a href="https://colab.research.google.com/github/jimmy93029/RL-theory-nycu/blob/main/Distributional_IQLtmp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # install

# %%
from google.colab import drive

drive.mount("/content/gdrive")
dataset_dir = '/content/gdrive/MyDrive'
# Out:
# Mounted at /content/gdrive

# %%
# !apt-get install -y \
    libgl1-mesa-dev \
    libgl1-mesa-glx \
    libglew-dev \
    libosmesa6-dev \
    software-properties-common
# !apt-get install -y patchelf
# !pip install free-mujoco-py

# %%
# !pip install Cmake
# !sudo apt-get install build-ssential python3-dev libssl-dev libssl-dev libffi-dev libxml2 libxml2-dev libxslt1-dev zlibig-dev

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.8

# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1
# !sudo apt-get install python3.8-distutils
# !sudo apt-get install python3-pip
# !python --version

# %%
# !sudo apt install python3.8-dev

# %%
# !pip install gym tqdm absl-py ml-collections tensorboardX d4rl
# !pip install git+https://github.com/rail-berkeley/d4rl@master

# %%
# !pip install -r /content/gdrive/MyDrive/implicit_Q_original/Implicit_Q_original_requirements.txt

# %%
# !pip install coolname torchvision
# !pip install tensorboard

# %% [markdown]
# # run

# %%
# !git clone https://github.com/rail-berkeley/d4rl.git

# ### edit dm_control version in d4rl setup.py
# !sed -i "s;dm_control @ git+git://github.com/deepmind/dm_control@master#egg=dm_control;dm_control==0.0.364896371;g" /content/d4rl/setup.py

# ### edit mjrl install in d4rl setup.py to use github's new https protocol instead of git SSH
# !sed -i "s;mjrl @ git+git://github.com/aravindr93/mjrl@master#egg=mjrl;mjrl @ git+https://github.com/aravindr93/mjrl@master#egg=mjrl;g" /content/d4rl/setup.py

# !pip install -e d4rl/.

# import d4rl

# !python /content/gdrive/MyDrive/unofficial_iql_distribution/main_iql.py --env antmaze-umaze-v0 --expectile 0.7 --temperature 3.0 --eval_freq 5000 --eval_episodes 10 --normalize --max_timesteps 10000
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# Actor loss: 3.812758025854929e-25
# Actor loss: 2.271785732622933e-13
# Actor loss: 58.172508239746094
# Actor loss: 58.38658142089844
#   0% 11/10000 [00:00<07:08, 23.29it/s]Actor loss: 58.18851089477539
# Actor loss: 56.47587203979492
# Actor loss: 56.49353790283203
# Actor loss: 56.07331848144531
# Actor loss: 56.39502716064453
#   0% 16/10000 [00:00<05:38, 29.51it/s]Actor loss: 55.046287536621094
# Actor loss: 0.021741755306720734
# Actor loss: 4.809098186342453e-07
# Actor loss: 53.51576614379883
# Actor loss: 53.84339904785156
#   0% 21/10000 [00:00<04:51, 34.27it/s]Actor loss: 52.82057571411133
# Actor loss: 52.3177604675293
# Actor loss: 50.59308624267578
# Actor loss: 52.37799072265625
# Actor loss: 50.3484992980957
# Actor loss: 52.15443420410156
# Actor loss: 47.935325622558594
#   0% 28/10000 [00:00<03:53, 42.64it/s]Actor loss: 50.726375579833984
# Actor loss: 13.875513076782227
# Actor loss: 47.13556671142578
# Actor loss: 45.787559509277344
# ...

# %% [markdown]
# # draw

# %%
# !pip install tensorboard

from tensorboard import program
import tensorflow as tf

# %load_ext tensorboard
# %tensorboard --logdir '/content/drive/My Drive/資訊工程學習資料/強化學習原理/課程作業 (謝秉均)/HW3/ddpg_cheetah/'
# !kill 48582
# %reload_ext tensorboard
# %tensorboard --logdir '/content/runs/tmp/antmaze-medium-play-v0/antmaze-medium-play-v0-05-20-04:55-bs256-s0-t10.0-e0.9-dynamic-fossa/'

# %% [markdown]
# # check

# %%
import os

file_path = "/content/gdrive/MyDrive/unofficial_iql/main_iql.py"  # 檔案路徑
if os.path.exists(file_path):
    print("檔案存在。")
else:
    print("檔案不存在。請檢查路徑是否正確。")
# Out:
# 檔案不存在。請檢查路徑是否正確。

# %%
import os

file_path = "/content/gdrive/MyDrive/unofficial_iql/main_iql.py"  # 檔案路徑
if os.path.exists(file_path):
    file_size = os.path.getsize(file_path)
    print("檔案大小:", file_size, "bytes")
else:
    print("檔案不存在。請檢查路徑是否正確。")
# Out:
# 檔案大小: 6734 bytes

# %%
import h5py

file_path = "/content/gdrive/MyDrive/unofficial_iql/main_iql.py"  # 檔案路徑

try:
    with h5py.File(file_path, 'r') as file:
        # 如果檔案成功打開，你可以在這裡進行相關的操作
        print("成功打開 HDF5 檔案。")
except Exception as e:
    print("打開 HDF5 檔案時出現錯誤:", e)
# Out:
# 打開 HDF5 檔案時出現錯誤: Unable to open file (file signature not found)

# %%
# !pip show d4rl h5py
# Out:
# Name: d4rl
# Version: 1.1
# Summary:
# Home-page:
# Author:
# Author-email:
# License:
# Location: /usr/local/lib/python3.8/dist-packages
# Requires: click, dm-control, gym, h5py, mujoco-py, numpy, pybullet, termcolor
# Required-by:
# ---
# Name: h5py
# Version: 3.11.0
# Summary: Read and write HDF5 files from Python
# Home-page:
# Author:
# Author-email: Andrew Collette <andrew.collette@gmail.com>
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.8/dist-packages
# Requires: numpy
# Required-by: d4rl
